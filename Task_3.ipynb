# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_excel('bank.xlsx')

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  int64
#  1   job             41188 non-null  object
#  2   marital         41188 non-null  object
#  3   education       41188 non-null  object
#  4   default         41188 non-null  object
#  5   housing         41188 non-null  object
#  6   loan            41188 non-null  object
#  7   contact         41188 non-null  object
#  8   month           41188 non-null  object
#  9   day_of_week     41188 non-null  object
#  10  duration        41188 non-null  int64
#  11  campaign        41188 non-null  int64
#  12  pdays           41188 non-null  int64
#  13  previous        41188 non-null  int64
#  14  poutcome        41188 non-null  object
#  15  emp.var.rate    41188 non-null  float64
#  16  cons.price.idx  41188 non-null  float64
#  17  cons.conf.idx   41188 non-null  float64
#  18  euribor3m       41188 non-null  float64
#  19  nr.employed     41188 non-null  float64
#  20  y               41188 non-null  object
# dtypes: float64(5), int64(5), object(11)
# memory usage: 6.6+ MB
# None

# %%
print(data.isnull().sum())
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
print(data.describe())
# Out:
#                age      duration      campaign         pdays      previous  \
# count  41188.00000  41188.000000  41188.000000  41188.000000  41188.000000
# mean      40.02406    258.285010      2.567593    962.475454      0.172963
# std       10.42125    259.279249      2.770014    186.910907      0.494901
# min       17.00000      0.000000      1.000000      0.000000      0.000000
# 25%       32.00000    102.000000      1.000000    999.000000      0.000000
# 50%       38.00000    180.000000      2.000000    999.000000      0.000000
# 75%       47.00000    319.000000      3.000000    999.000000      0.000000
# max       98.00000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  41188.000000    41188.000000   41188.000000  41188.000000  41188.000000
# mean       0.081886       93.575664     -40.502600      3.621291   5167.035911
# std        1.570960        0.578840       4.628198      1.734447     72.251528
# min       -3.400000       92.201000     -50.800000      0.634000   4963.600000
# 25%       -1.800000       93.075000     -42.700000      1.344000   5099.100000
# 50%        1.100000       93.749000     -41.800000      4.857000   5191.000000
# 75%        1.400000       93.994000     -36.400000      4.961000   5228.100000
# max        1.400000       94.767000     -26.900000      5.045000   5228.100000

# %%
print("Number of columns: ",len(data.columns))
print("Number of rows: ",len(data))
# Out:
# Number of columns:  21
# Number of rows:  41188

# %%
print(data.columns)
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y'],
#       dtype='object')

# %%
data.sample(10)
# Out:
#        age          job   marital            education  default housing loan  \
# 11148   45  blue-collar   married             basic.9y  unknown     yes  yes
# 1438    38   technician   married    university.degree  unknown      no   no
# 32738   39  blue-collar   married             basic.4y       no      no   no
# 25525   29   technician    single  professional.course       no     yes  yes
# 32308   43  blue-collar   married             basic.9y       no      no   no
# 5266    35       admin.   married          high.school  unknown      no   no
# 23151   55   management   married    university.degree       no     yes   no
# 18882   38   technician   married  professional.course       no      no   no
# 29614   31     services  divorced          high.school       no      no   no
# 17046   45   technician  divorced              unknown  unknown      no   no
#
#          contact month day_of_week  ...  campaign  pdays  previous  \
# 11148  telephone   jun         thu  ...         1    999         0
# 1438   telephone   may         thu  ...         2    999         0
# 32738   cellular   may         mon  ...         1    999         0
# 25525  telephone   nov         wed  ...         1    999         0
# 32308   cellular   may         fri  ...         1    999         0
# 5266   telephone   may         fri  ...         3    999         0
# 23151   cellular   aug         tue  ...         2    999         0
# 18882   cellular   aug         mon  ...         3    999         0
# 29614   cellular   apr         mon  ...         1    999         0
# 17046   cellular   jul         fri  ...         2    999         0
#
#           poutcome emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 11148  nonexistent          1.4          94.465          -41.8      4.961
# 1438   nonexistent          1.1          93.994          -36.4      4.855
# 32738  nonexistent         -1.8          92.893          -46.2      1.299
# 25525  nonexistent         -0.1          93.200          -42.0      4.120
# 32308  nonexistent         -1.8          92.893          -46.2      1.313
# 5266   nonexistent          1.1          93.994          -36.4      4.857
# 23151  nonexistent          1.4          93.444          -36.1      4.965
# 18882  nonexistent          1.4          93.444          -36.1      4.970
# 29614  nonexistent         -1.8          93.075          -47.1      1.405
# 17046  nonexistent          1.4          93.918          -42.7      4.962
#
#        nr.employed   y
# 11148       5228.1  no
# 1438        5191.0  no
# 32738       5099.1  no
# 25525       5195.8  no
# 32308       5099.1  no
# 5266        5191.0  no
# 23151       5228.1  no
# 18882       5228.1  no
# 29614       5099.1  no
# 17046       5228.1  no
#
# [10 rows x 21 columns]

# %%
sns.histplot(data, x='age', hue='y', bins=20, kde=True, palette=['royalblue', 'gold'])
plt.title("Age Distribution and Deposits\n")
plt.xlabel('Age')
plt.ylabel('Deposits')
plt.show()

# %%
plt.figure(figsize=(12,5))
sns.countplot(data, x='job',hue='y', palette=['violet','peachpuff'], edgecolor='black')
plt.xlabel('Occupation')
plt.ylabel('Deposits')
plt.title("Occupation Distribution and Deposits\n")
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.countplot(data, x='marital',hue='y', palette=['lightcoral' , 'lightskyblue'],  edgecolor='black')
plt.xlabel('Marital status')
plt.ylabel('Count')
plt.title("Marital Status and Deposits\n")
plt.show()

# %%
plt.figure(figsize=(11,5))
sns.countplot(data, x='education',hue='y', palette=['olivedrab','lightgreen'], edgecolor='black')
plt.xlabel('Education')
plt.ylabel('Count')
plt.title("Education Status and Deposits\n")
plt.show()

# %%
plt.figure(figsize=(11,5))
sns.countplot(data, x='housing',hue='y', palette=['dodgerblue','aqua'], edgecolor='black')
plt.xlabel('Housing loan')
plt.ylabel('Count')
plt.title("Housing Loan Distribution and Deposits\n")
plt.show()

# %%
plt.figure(figsize=(11,5))
sns.countplot(data, x='loan',hue='y', palette=['bisque','lightcoral'], edgecolor='black')
plt.xlabel('Personal loan')
plt.ylabel('Count')
plt.title("Personal Loan Distribution and Deposits\n")
plt.show()

# %%
yes_no=data['y'].value_counts()
ex=[0.1,0.1]
c=['cyan', 'wheat']
l=['No', 'Yes']
plt.pie(yes_no, explode=ex, colors=c, autopct='%.0f%%', labels=l)
plt.show()

# %%
obj_cols = data.select_dtypes("object").columns
obj_cols
# Out:
# Index(['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact',
#        'month', 'day_of_week', 'poutcome', 'y'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
data[obj_cols]=data[obj_cols].apply(le.fit_transform)

# %%
X=data.iloc[:,:-1].values
y=data.iloc[:,-1].values

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X = sc.fit_transform(X)
X_data = pd.DataFrame(X)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split((X),y,test_size=0.2,random_state=0)

# %%
from sklearn.tree import DecisionTreeClassifier
classifier=DecisionTreeClassifier(criterion= 'entropy', max_depth= 5, min_samples_leaf = 3, random_state=0)
classifier.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=5, min_samples_leaf=3,
#                        random_state=0)

# %%
y_pred=classifier.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
cm=confusion_matrix(y_test, y_pred)
ConfusionMatrixDisplay(cm, display_labels=classifier.classes_).plot()
plt.show()

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, roc_curve
accuracy = accuracy_score(y_test, y_pred)*100
print('accuracy', accuracy)
precision = precision_score(y_test, y_pred, average='weighted')*100
print('precision', precision)
recall = recall_score(y_test, y_pred, average='weighted')*100
print('recall', recall)
f1 = f1_score(y_test, y_pred, average='weighted')*100
print('f1',f1)
roc_auc_nb = roc_auc_score(y_test, classifier.predict_proba(X_test)[:, 1], multi_class='ovr', average='weighted')*100
print('roc_auc_nb',roc_auc_nb)
# Out:
# accuracy 91.854819130857
# precision 91.39554933403214
# recall 91.854819130857
# f1 91.57840063439721
# roc_auc_nb 93.54295117229577

# %%
X_=data.iloc[:,:-1]
from sklearn import tree
fig = plt.figure(figsize=(10,10))
t= tree.plot_tree(classifier,filled=True,feature_names=X_.columns)

# %%
rng = pd.date_range('2023-01-01', periods=100, freq='D')
ts = pd.DataFrame(np.random.randn(len(rng)), index=rng, columns=['value'])

monthly_resampled = ts.resample('M').mean()
print(monthly_resampled)
# Out:
#                value
# 2023-01-31 -0.069504
# 2023-02-28 -0.248779
# 2023-03-31  0.098843
# 2023-04-30  0.331589
